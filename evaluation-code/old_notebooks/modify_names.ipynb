# %%
# %load_ext autoreload
# %autoreload 2

# %%
# from handledata import gesture_data
import datatools.load_gestures as load
import numpy as np  
from handledata.gesture_data import GestureData

# %%
name = 'g0'
# For each digit load gesture 
for d in load.DigitNames:
    digits_for_name = load.load_digits_for_candidate(name, d)
    # digits_for_name is a list [[(name, gesture_data)]]
    # gesture_dicts data is a list of gesture data dicts
    gesture_dicts = digits_for_name[0][1]
    # Convert back to data object
    gestures = [GestureData.load_from_dict(gesture_dict) for gesture_dict in gesture_dicts] 
    gestures[0].plot()
    # Change name
    # for gesture in gestures:
        # gesture.change_name(new_name)
        # gesture.save_to_file()
        # counter += 1
    # Save to file
    
    # gestures[0].plot()

# Rename each candidate
print(f"Changed {counter} files.")
# Save into file, don't remove old yet.
# Out:
# Saving gesture data to file at: ./dataset/digits/#0/right_hand/candidate_g4.pickle
# Saving gesture data to file at: ./dataset/digits/#0/right_hand/candidate_g4.pickle
# Saving gesture data to file at: ./dataset/digits/#0/right_hand/candidate_g4.pickle
# Saving gesture data to file at: ./dataset/digits/#0/right_hand/candidate_g4.pickle
# Saving gesture data to file at: ./dataset/digits/#0/right_hand/candidate_g4.pickle
# Saving gesture data to file at: ./dataset/digits/#0/right_hand/candidate_g4.pickle
# Saving gesture data to file at: ./dataset/digits/#0/right_hand/candidate_g4.pickle
# Saving gesture data to file at: ./dataset/digits/#0/right_hand/candidate_g4.pickle
# Saving gesture data to file at: ./dataset/digits/#0/right_hand/candidate_g4.pickle
# Saving gesture data to file at: ./dataset/digits/#0/right_hand/candidate_g4.pickle
# Saving gesture data to file at: ./dataset/digits/#0/right_hand/candidate_g4.pickle
# ...
